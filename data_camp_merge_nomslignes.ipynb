# %%
# %matplotlib inline
import imp
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Data

# %%
df=pd.read_csv('validations-sur-le-reseau-ferre-nombre-de-validations-par-jour-1er-semestre-2017.csv',sep=";")
data_emplacement_gares=pd.read_csv('emplacement-des-gares-idf-data-generalisee.csv',sep=";")

# %%
df.head()
# Out:
#          JOUR  CODE_STIF_TRNS CODE_STIF_RES CODE_STIF_ARRET    LIBELLE_ARRET  \
# 0  2019-04-04             800           852              62         BELLEVUE
# 1  2019-04-04             800           852              62         BELLEVUE
# 2  2019-04-04             800           852             657  PLAISIR-GRIGNON
# 3  2019-04-04             800           852             657  PLAISIR-GRIGNON
# 4  2019-04-04             800           852             657  PLAISIR-GRIGNON
#
#    ID_REFA_LDA CATEGORIE_TITRE     NB_VALD
# 0      69528.0       AMETHYSTE          20
# 1      69528.0       IMAGINE R         424
# 2      64199.0               ?         113
# 3      64199.0       AMETHYSTE          68
# 4      64199.0     AUTRE TITRE  Moins de 5

# %%
data_emplacement_gares.head()
# Out:
#                      Geo Point  \
# 0  48.8473545169,2.38680844578
# 1  48.8608062913,2.34110859163
# 2  48.8498504878,2.22123268327
# 3  48.9160965041,2.51506144619
# 4     48.8652537861,2.37458197
#
#                                            Geo Shape  OBJECTID  id_ref_zdl  \
# 0  {"type": "Point", "coordinates": [2.3868084457...         4       44637
# 1  {"type": "Point", "coordinates": [2.3411085916...         7       44645
# 2  {"type": "Point", "coordinates": [2.2212326832...        31       51611
# 3  {"type": "Point", "coordinates": [2.5150614461...        35      411280
# 4  {"type": "Point", "coordinates": [2.3745819699...        58       58725
#
#               nom_long                label        idrefliga        idrefligc  \
# 0      REUILLY-DIDEROT      Reuilly-Diderot  A01534 / A01541  C01371 / C01378
# 1        LOUVRE-RIVOLI        Louvre-Rivoli           A01534           C01371
# 2           LES MILONS           Les Milons           A01192           C01390
# ...

# %%
df_merge= df.merge(data_emplacement_gares, left_on='LIBELLE_ARRET', right_on='nom_long')

# %%
df_merge.head()
# Out:
#          JOUR  CODE_STIF_TRNS CODE_STIF_RES CODE_STIF_ARRET LIBELLE_ARRET  \
# 0  2019-04-04             800           852              62      BELLEVUE
# 1  2019-04-04             800           852              62      BELLEVUE
# 2  2019-04-05             800           852              62      BELLEVUE
# 3  2019-04-05             800           852              62      BELLEVUE
# 4  2019-04-05             800           852              62      BELLEVUE
#
#    ID_REFA_LDA CATEGORIE_TITRE NB_VALD                    Geo Point  \
# 0      69528.0       AMETHYSTE      20  48.8189478001,2.22980800647
# 1      69528.0       IMAGINE R     424  48.8189478001,2.22980800647
# 2      69528.0               ?      11  48.8189478001,2.22980800647
# 3      69528.0       IMAGINE R     447  48.8189478001,2.22980800647
# 4      69528.0             TST      38  48.8189478001,2.22980800647
#
#                                            Geo Shape  ...  terrer  termetro  \
# ...

# %%
df_merge.columns
# Out:
# Index(['JOUR', 'CODE_STIF_TRNS', 'CODE_STIF_RES', 'CODE_STIF_ARRET',
#        'LIBELLE_ARRET', 'ID_REFA_LDA', 'CATEGORIE_TITRE', 'NB_VALD',
#        'Geo Point', 'Geo Shape', 'OBJECTID', 'id_ref_zdl', 'nom_long', 'label',
#        'idrefliga', 'idrefligc', 'res_com', 'mode_', 'fer', 'train', 'rer',
#        'metro', 'tramway', 'navette', 'val', 'terfer', 'tertrain', 'terrer',
#        'termetro', 'tertram', 'ternavette', 'terval', 'exploitant',
#        'principal', 'idf', 'x', 'y'],
#       dtype='object')

# %%
df_merge.shape
# Out:
# (828604, 37)
